# %% [markdown]
# # Getting Data from Twitter Using Rapid API

# %%
import http.client
import json
import pandas as pd
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize


# Function to fetch tweets using RapidAPI
def fetch_tweets(query, min_retweets=10, min_likes=10, limit=10, start_date="2022-01-01", language="en"):
    conn = http.client.HTTPSConnection("twitter154.p.rapidapi.com")
    headers = {
        'x-rapidapi-key': "5c75308bf6msh2b302bcfa9a8e0ep109e11jsn949c33074b98",
        'x-rapidapi-host': "twitter154.p.rapidapi.com"
    }
    
    endpoint = f"/search/search/continuation?query={query}&section=top&min_retweets={min_retweets}&limit={limit}&min_likes={min_likes}&start_date={start_date}&language={language}"
    conn.request("GET", endpoint, headers=headers)
    res = conn.getresponse()
    
    if res.status != 200:
        raise Exception(f"API request failed with status {res.status}")
    
    data = res.read()
    return json.loads(data)

# Fetch tweets containing the hashtag #python
tweets_data = fetch_tweets("%23NeetUG24Controversy")

# Extract the tweet texts
tweets = [tweet['text'] for tweet in tweets_data.get('results', [])]

# Check if tweets are retrieved
if not tweets:
    raise Exception("No tweets were retrieved from the API")

# Convert to DataFrame for convenience
tweets_df = pd.DataFrame(tweets, columns=['Tweet'])
tweets_df.head()
# Out:
#                                                Tweet
# 0  Standing up for NEET 2024 aspirants 💯. Heading...
# 1  If you Support Students then repost and like a...
# 2  #NEET students are protesting  in Varanasi, Ut...
# 3  Ab ye omr ki sheet pe questions ki speed kha s...
# 4  Your voice matters. Come forward and join the ...

# %%
tweets_df
# Out:
#                                                Tweet
# 0  Standing up for NEET 2024 aspirants 💯. Heading...
# 1  If you Support Students then repost and like a...
# 2  #NEET students are protesting  in Varanasi, Ut...
# 3  Ab ye omr ki sheet pe questions ki speed kha s...
# 4  Your voice matters. Come forward and join the ...
# 5  There is a possibility that the NEET 2024 exam...
# 6  Stay united; together, we will win this fight ...
# 7  Big Scam in NEET 2024\n#NEET students are prot...
# 8  The Ministry of Education announced the format...
# 9  #NEET students are protesting  in Varanasi, Ut...

# %%
stemmer = PorterStemmer()

def stem_words(text):
    tokens = word_tokenize(text)
    stemmed = [stemmer.stem(token) for token in tokens]
    return ' '.join(stemmed)

tweets_df['Stemmed'] = tweets_df['Tweet'].apply(stem_words)
tweets_df.head()
# Out:
#                                                Tweet
# 0  Standing up for NEET 2024 aspirants 💯. Heading...  \
# 1  If you Support Students then repost and like a...
# 2  #NEET students are protesting  in Varanasi, Ut...
# 3  Ab ye omr ki sheet pe questions ki speed kha s...
# 4  Your voice matters. Come forward and join the ...
#
#                                              Stemmed
# 0  stand up for neet 2024 aspir 💯 . head to delhi...
# 1  if you support student then repost and like as...
# 2  # neet student are protest in varanasi , uttar...
# 3  ab ye omr ki sheet pe question ki speed kha se...
# 4  your voic matter . come forward and join the p...

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_words(text):
    tokens = word_tokenize(text)
    lemmatized = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(lemmatized)

tweets_df['Lemmatized'] = tweets_df['Tweet'].apply(lemmatize_words)
tweets_df.head()
# Out:
#                                                Tweet
# 0  Standing up for NEET 2024 aspirants 💯. Heading...  \
# 1  If you Support Students then repost and like a...
# 2  #NEET students are protesting  in Varanasi, Ut...
# 3  Ab ye omr ki sheet pe questions ki speed kha s...
# 4  Your voice matters. Come forward and join the ...
#
#                                              Stemmed
# 0  stand up for neet 2024 aspir 💯 . head to delhi...  \
# 1  if you support student then repost and like as...
# 2  # neet student are protest in varanasi , uttar...
# 3  ab ye omr ki sheet pe question ki speed kha se...
# 4  your voic matter . come forward and join the p...
#
#                                           Lemmatized
# 0  Standing up for NEET 2024 aspirant 💯 . Heading...
# 1  If you Support Students then repost and like a...
# 2  # NEET student are protesting in Varanasi , Ut...
# 3  Ab ye omr ki sheet pe question ki speed kha se...
# 4  Your voice matter . Come forward and join the ...

# %%
# Display some examples to compare
for index, row in tweets_df.iterrows():
    print(f"Original Tweet: {row['Tweet']}\n")
    print(f"Stemmed Tweet: {row['Stemmed']}\n")
    print(f"Lemmatized Tweet: {row['Lemmatized']}\n")
    print("\n\n\n")
# Out:
# Original Tweet: Standing up for NEET 2024 aspirants 💯. Heading to Delhi with my team to fight for justice in the Supreme Court.
#
# #NeetUG24Controversy #neetresult2024, #Neet_exam #NEETExamResult #NEET_परीक्षा_परिणाम #NEET https://t.co/zJhOmLsbpk
#
# Stemmed Tweet: stand up for neet 2024 aspir 💯 . head to delhi with my team to fight for justic in the suprem court . # neetug24controversi # neetresult2024 , # neet_exam # neetexamresult # neet_परीक्षा_परिणाम # neet http : //t.co/zjhomlsbpk
#
# Lemmatized Tweet: Standing up for NEET 2024 aspirant 💯 . Heading to Delhi with my team to fight for justice in the Supreme Court . # NeetUG24Controversy # neetresult2024 , # Neet_exam # NEETExamResult # NEET_परीक्षा_परिणाम # NEET http : //t.co/zJhOmLsbpk
#
#
#
#
#
# Original Tweet: If you Support Students then repost and like as you can 🔙
#
# and also comment with this hastag.
#
# #NeetUG24Controversy #NEETExamResult
# #NEET_परीक्षा_परिणाम #NEET_पेपर_रद्द_करो
# #NeetUG24Controversy #RENEET https://t.co/U2hYYlTgSZ
#
# Stemmed Tweet: if you support student then repost and like as you can 🔙 and also comment with thi hastag . # neetug24controversi # neetexamresult # neet_परीक्षा_परिणाम # neet_पेपर_रद्द_करो # neetug24controversi # reneet http : //t.co/u2hyyltgsz
#
# Lemmatized Tweet: If you Support Students then repost and like a you can 🔙 and also comment with this hastag . # NeetUG24Controversy # NEETExamResult # NEET_परीक्षा_परिणाम # NEET_पेपर_रद्द_करो # NeetUG24Controversy # RENEET http : //t.co/U2hYYlTgSZ
#
#
#
#
#
# Original Tweet: #NEET students are protesting  in Varanasi, Uttar Pradesh. 🔥
#
# The students are demanding that the NEET scam be investigated by the CBI and the NEET exam be conducted again.
#
# #NEET_परीक्षा_परिणाम #NEET_पेपर_रद्द_करो
# #NeetUG24Controversy #RENEET https://t.co/rFrZOav32W
#
# Stemmed Tweet: # neet student are protest in varanasi , uttar pradesh . 🔥 the student are demand that the neet scam be investig by the cbi and the neet exam be conduct again . # neet_परीक्षा_परिणाम # neet_पेपर_रद्द_करो # neetug24controversi # reneet http : //t.co/rfrzoav32w
#
# Lemmatized Tweet: # NEET student are protesting in Varanasi , Uttar Pradesh . 🔥 The student are demanding that the NEET scam be investigated by the CBI and the NEET exam be conducted again . # NEET_परीक्षा_परिणाम # NEET_पेपर_रद्द_करो # NeetUG24Controversy # RENEET http : //t.co/rFrZOav32W
#
#
#
#
#
# Original Tweet: Ab ye omr ki sheet pe questions ki speed kha se bta de rhe hai, ki Kuan questions kitne Samy me Kiya...
#
# Every Neet aspirants - RT maxx🔁
#
# #NEET_परीक्षा_परिणाम #NEET_पेपर_रद्द_करो
# #NeetUG24Controversy #RENEET #NeetUG24Controversy
# #NEET #NEET_पेपर_रद्द_करो #pressrelease https://t.co/oknlOQizJ2
#
# Stemmed Tweet: ab ye omr ki sheet pe question ki speed kha se bta de rhe hai , ki kuan question kitn sami me kiya ... everi neet aspir - rt maxx🔁 # neet_परीक्षा_परिणाम # neet_पेपर_रद्द_करो # neetug24controversi # reneet # neetug24controversi # neet # neet_पेपर_रद्द_करो # pressreleas http : //t.co/oknloqizj2
#
# Lemmatized Tweet: Ab ye omr ki sheet pe question ki speed kha se bta de rhe hai , ki Kuan question kitne Samy me Kiya ... Every Neet aspirant - RT maxx🔁 # NEET_परीक्षा_परिणाम # NEET_पेपर_रद्द_करो # NeetUG24Controversy # RENEET # NeetUG24Controversy # NEET # NEET_पेपर_रद्द_करो # pressrelease http : //t.co/oknlOQizJ2
#
#
#
#
#
# Original Tweet: Your voice matters. Come forward and join the protest now. Together, we can make a difference.
#
# Repost 🔁  If you Stand with Us 🔙
#
#  #NeetUG24Controversy #NEETExamResult
# #NEET_परीक्षा_परिणाम #NEET_पेपर_रद्द_करो
# #NeetUG24Controversy #RENEET https://t.co/sVLvNCVfZO
#
# Stemmed Tweet: your voic matter . come forward and join the protest now . togeth , we can make a differ . repost 🔁 if you stand with us 🔙 # neetug24controversi # neetexamresult # neet_परीक्षा_परिणाम # neet_पेपर_रद्द_करो # neetug24controversi # reneet http : //t.co/svlvncvfzo
#
# Lemmatized Tweet: Your voice matter . Come forward and join the protest now . Together , we can make a difference . Repost 🔁 If you Stand with Us 🔙 # NeetUG24Controversy # NEETExamResult # NEET_परीक्षा_परिणाम # NEET_पेपर_रद्द_करो # NeetUG24Controversy # RENEET http : //t.co/sVLvNCVfZO
#
#
#
#
#
# Original Tweet: There is a possibility that the NEET 2024 exam will be reconducted. Be prepared for it.
#
# #NEET #NEET_परीक्षा_परिणाम #NTA #RENEET #NeetUG24Controversy https://t.co/fOh8NbzbuE
#
# Stemmed Tweet: there is a possibl that the neet 2024 exam will be reconduct . be prepar for it . # neet # neet_परीक्षा_परिणाम # nta # reneet # neetug24controversi http : //t.co/foh8nbzbu
#
# Lemmatized Tweet: There is a possibility that the NEET 2024 exam will be reconducted . Be prepared for it . # NEET # NEET_परीक्षा_परिणाम # NTA # RENEET # NeetUG24Controversy http : //t.co/fOh8NbzbuE
#
#
#
#
#
# Original Tweet: Stay united; together, we will win this fight against injustice.
#
# #NEET_परीक्षा_परिणाम #NEET #NeetUG24Controversy  #NEETResult #NEETExam #Neet2024 #NTA https://t.co/xTdyDTnSDS
#
# Stemmed Tweet: stay unit ; togeth , we will win thi fight against injustic . # neet_परीक्षा_परिणाम # neet # neetug24controversi # neetresult # neetexam # neet2024 # nta http : //t.co/xtdydtnsd
#
# Lemmatized Tweet: Stay united ; together , we will win this fight against injustice . # NEET_परीक्षा_परिणाम # NEET # NeetUG24Controversy # NEETResult # NEETExam # Neet2024 # NTA http : //t.co/xTdyDTnSDS
#
#
#
#
#
# Original Tweet: Big Scam in NEET 2024
# #NEET students are protesting  in Varanasi, Uttar Pradesh. 🔥
#
# #NEET_पेपर_रद्द_करो  #NeetUG24Controversy
# #RENEET #ModiSarkaar https://t.co/yXAH6q0U98
#
# Stemmed Tweet: big scam in neet 2024 # neet student are protest in varanasi , uttar pradesh . 🔥 # neet_पेपर_रद्द_करो # neetug24controversi # reneet # modisarkaar http : //t.co/yxah6q0u98
#
# Lemmatized Tweet: Big Scam in NEET 2024 # NEET student are protesting in Varanasi , Uttar Pradesh . 🔥 # NEET_पेपर_रद्द_करो # NeetUG24Controversy # RENEET # ModiSarkaar http : //t.co/yXAH6q0U98
#
#
#
#
#
# Original Tweet: The Ministry of Education announced the formation of a Grievance Redressal Committee to address concerns related to the NEET results after widespread protests by students in many cities. Hope the committee will address the concerns of the students.
#  #NeetUG24Controversy #RENEET https://t.co/UYNKode8Mp
#
# Stemmed Tweet: the ministri of educ announc the format of a grievanc redress committe to address concern relat to the neet result after widespread protest by student in mani citi . hope the committe will address the concern of the student . # neetug24controversi # reneet http : //t.co/uynkode8mp
#
# Lemmatized Tweet: The Ministry of Education announced the formation of a Grievance Redressal Committee to address concern related to the NEET result after widespread protest by student in many city . Hope the committee will address the concern of the student . # NeetUG24Controversy # RENEET http : //t.co/UYNKode8Mp
#
#
#
#
#
# Original Tweet: #NEET students are protesting  in Varanasi, Uttar Pradesh. 🔥
#
# The students are demanding that the NEET scam be investigated by the CBI and the NEET exam be conducted again.
#
# Every Neet aspirants - RT maxx🔁
# #NEET_परीक्षा_परिणाम #NEET_पेपर_रद्द_करो
# #NeetUG24Controversy #RENEET https://t.co/VKAbCUkXDV
#
# Stemmed Tweet: # neet student are protest in varanasi , uttar pradesh . 🔥 the student are demand that the neet scam be investig by the cbi and the neet exam be conduct again . everi neet aspir - rt maxx🔁 # neet_परीक्षा_परिणाम # neet_पेपर_रद्द_करो # neetug24controversi # reneet http : //t.co/vkabcukxdv
#
# Lemmatized Tweet: # NEET student are protesting in Varanasi , Uttar Pradesh . 🔥 The student are demanding that the NEET scam be investigated by the CBI and the NEET exam be conducted again . Every Neet aspirant - RT maxx🔁 # NEET_परीक्षा_परिणाम # NEET_पेपर_रद्द_करो # NeetUG24Controversy # RENEET http : //t.co/VKAbCUkXDV

# %% [markdown]
# ### Observations
#
# 1. **Stemming**:
#     - The process reduces words to their root form by removing suffixes. For example, "aspirants" becomes "aspir", "heading" becomes "head", "justice" becomes "justic", and "supreme" becomes "suprem".
#     - Stemming can sometimes produce non-standard or incomplete words, which may not always be meaningful.
# 2. **Lemmatization**:
#     - This technique reduces words to their base or dictionary form. For instance, "aspirants" is lemmatized to "aspirant", "Heading" remains "Heading", and "justice" and "supreme" remain unchanged.
#     - Lemmatization is more contextually aware and produces words that are valid and meaningful.
#
# ### Inferences
#
# 1. **Stemming**:
#     - Stemming is a more aggressive technique and can sometimes distort the meaning of words due to over-simplification.
#     - It is useful when the goal is to reduce computational complexity and the exact word form is less critical.
# 2. **Lemmatization**:
#     - Lemmatization preserves the semantic meaning of words better than stemming. It ensures that the words are valid and contextually appropriate.
#     - It is more suitable for applications where understanding and preserving the meaning of words is crucial, such as in sentiment analysis or text summarization.
#
# ### General Understanding
#
# - Both stemming and lemmatization are essential text preprocessing steps in Natural Language Processing (NLP).
# - The choice between stemming and lemmatization depends on the specific requirements of the task at hand.
# - For tasks requiring precise meaning, like named entity recognition or topic modeling, lemmatization is preferred.
# - For tasks focused on general text normalization and reducing dimensionality, stemming might suffice.
